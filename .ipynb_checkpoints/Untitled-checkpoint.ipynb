# %%
from pyresparser import ResumeParser
data = ResumeParser('./北京邮电大学-王欣-硕士-信通院.docx').get_extracted_data()
# Out:
# D:\anaconda\Lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.9). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
print(data)
# Out:
# {'name': '王     ', 'email': 'wxin_bupt@163.com', 'mobile_number': '188-0102', 'skills': ['Shell'], 'college_name': None, 'degree': None, 'designation': None, 'experience': None, 'company_names': ['欣 个人信息'], 'no_of_pages': None, 'total_experience': 0}

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
pip install sapcy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sapcy (from versions: none)
# ERROR: No matching distribution found for sapcy

# %%
python -m spacy download en_core_web_sm
# Out:
#   Cell In[3], line 1
#     python -m spacy download en_core_web_sm
#               ^
# SyntaxError: invalid syntax

# %%
#coding: utf-8

import sys
import base64
import requests
import json

def test_parser(url, fname, appcode):
    """
    请求简历解析接口，请求字段：
    - file_name: 必填，简历文件名（请确保后缀正确）；
    - file_cont: 必填，经based64编码的简历文件内容；
    - need_avatar: 可选，是否需要解析头像，0为不需要，1为需要，默认为0；
    - 其他可选字段可参考官网：https://www.resumesdk.com/docs/rs-parser.html#reqType
    使用阿里云接口的修改：
    - Authorization: 必填，使用APPCODE 替换headers中的uid和pwd字段；
    """

    # 读取文件内容，构造请求
    cont = open(fname, 'rb').read()
    base_cont = base64.b64encode(cont)
    base_cont = base_cont.decode('utf-8') if sys.version.startswith('3') else base_cont     #兼容python2与python3
    
    headers = {'Authorization': 'APPCODE ' + appcode}

    data = {'file_name': fname,
            'file_cont': base_cont,
            'need_avatar': 0,
            }
    
    # 发送请求
    res = requests.post(url, data=json.dumps(data), headers=headers)
    
    # 解析结果
    http_code = res.status_code
    if http_code != 200:
        print("http status code:", res.status_code)
    else:
        res_js = json.loads(res.text)
        print('result:\n%s\n'%(json.dumps(res_js, indent=2, ensure_ascii=False)))
    
if __name__ == '__main__':
    url = 'http://resumesdk.market.alicloudapi.com/ResumeParse'    # 阿里云接口地址
    fname = 'D:/BaiduNetdiskDownload/岗位信息样例库/北京邮电大学-王欣-硕士-信通院.docx'  # 替换为你的文件名
    appcode = '9a95262e27054f318e64757acd129825'  # 替换为你的AppCode
    test_parser(url, fname, appcode)
# Out:
# http status code: 404

# %%
import base64
import requests
import json

def test_parse(url, fname):
    # 读取文件内容
    cont = open(fname, 'rb').read()
    base_cont = base64.b64encode(cont).decode('utf8')  # python3
        
    # 构造json请求
    data = {
            'file_name': fname,         # 简历文件名（需包含正确的后缀名）
            'file_cont': base_cont,     # 简历内容（base64编码的简历内容）
            'need_avatar': 0,            # 是否需要提取头像图片
            'ocr_type': 1,                 # 1为高级ocr
            }
    
    appcode = '9a95262e27054f318e64757acd129825'
    headers = {'Authorization': 'APPCODE ' + appcode,
               'Content-Type': 'application/json; charset=UTF-8',
               }
    # 发送请求
    data_js = json.dumps(data)
    res = requests.post(url=url, data=data_js, headers=headers)
    
    # 解析结果
    res_js = json.loads(res.text)
    print(json.dumps(res_js, indent=4, ensure_ascii=False))      # 打印全部结果

    return res_js
        

url = 'http://resumesdk.market.alicloudapi.com/ResumeParser'
fname = u'D:/BaiduNetdiskDownload/岗位信息样例库/北京邮电大学-王欣-硕士-信通院.docx'
resume_data = test_parse(url, fname)
# Out:
# {
#     "status": {
#         "code": 200,
#         "message": "success"
#     },
#     "result": {
#         "name": "王欣",
#         "email": "wxin_bupt@163.com",
#         "phone": "18801025570",
#         "gender": "女",
#         "birthday": "1989.03",
#         "living_address": "北京市海淀区西土城路10号北京邮电大学29舍1103室",
#         "hometown_address": "天津市河北区",
#         "race": "汉族",
#         "polit_status": "中共党员",
#         "degree": "硕士",
#         "surname": "王",
#         "age": "35",
#         "hukou_address": "天津市河北区",
#         "city": "北京市",
#         "city_norm": "中国-北京-北京市-海淀区",
#         "grad_time": "2014.03",
#         "college": "北京邮电大学",
#         "major": "信号与信息处理",
#         "college_type": "2",
#         "college_rank": "26",
#         "work_year": "0",
#         "work_year_inf": "0",
#         "work_position": "软件开发实习生",
#         "work_pos_type_p": "软件工程师",
#         "work_company": "中国科学院软件研究所",
#         "work_job_nature": "实习",
#         "work_year_norm": "0",
#         "living_address_norm": "中国-北京-北京市-海淀区",
#         "hukou_address_norm": "中国-天津-天津市",
#         "hometown_address_norm": "中国-天津-天津市",
#         "languages": "英语",
#         "english_level": "大学英语6级",
#         "resume_type": "0",
#         "resume_name": "cv20240409_120200935_524.docx",
#         "resume_parse_time": "2024-04-09 12:02:01",
#         "resume_integrity": "79",
#         "education_objs": [
#             {
#                 "start_date": "2011.09",
#                 "end_date": "2014.03",
#                 "edu_college": "北京邮电大学",
#                 "edu_college_type": "2",
#                 "edu_college_rank": "26",
#                 "edu_college_dept": "信息与通信工程学院",
#                 "edu_major": "信号与信息处理",
#                 "edu_degree": "硕士",
#                 "edu_degree_norm": "硕士研究生",
#                 "edu_content": "荣获一等奖学金累计3次(10%)"
#             },
#             {
#                 "start_date": "2007.09",
#                 "end_date": "2011.07",
#                 "edu_college": "大连理工大学",
#                 "edu_college_type": "1",
#                 "edu_college_rank": "30",
#                 "edu_college_dept": "创新实验学院",
#                 "edu_major": "电子信息工程",
#                 "edu_degree": "本科",
#                 "edu_degree_norm": "本科",
#                 "edu_content": "成绩排名1/57,获大连理工大学研究生保送资格\n· 荣获校学习一等奖学金累计3次(5%)、校优秀毕业生、校军训优秀个人称号、高教社杯全国大学生数学建模竞赛辽宁省一等奖、大连理工大学第十七届数学建模竞赛二等奖"
#             }
#         ],
#         "job_exp_objs": [
#             {
#                 "start_date": "2013.07",
#                 "end_date": "2013.10",
#                 "job_cpy": "中国科学院软件研究所",
#                 "job_position": "软件开发实习生",
#                 "job_pos_type_p": "软件工程师",
#                 "job_dept": "总体部",
#                 "job_nature": "实习",
#                 "job_duration": "3个月",
#                 "job_content": "在Hadoop集群上运行Purdue MapReduce Benchmarks上13个实例程序,并分析其相应功能;\n· 可视化软件开发,包括设置输入、输入与应用绑定、上传输入至hdfs、修改运行设置、多应用同步运行、应用运行进度显示、输出预览、添加删除应用等功能。\n收获:Hadoop、C++、QT、Linux Shell"
#             }
#         ],
#         "proj_exp_objs": [
#             {
#                 "start_date": "2012.06",
#                 "end_date": "2013.12",
#                 "proj_name": "话音质量客观评价系统研制",
#                 "proj_position": "软件开发负责人",
#                 "proj_content": "研究一种考虑网络损伤的话音质量客观评价算法;\n· 设计并实现失真话音源发生器,使用MFC完成电路噪声、削波、滤波和单频噪音的模拟显示;\n· 使用MySQL构建原始与失真话音数据库;\n· 开发基于Win32平台的客观评价系统,使用QT完成五大模块设计,即标准测试源、任意源评测、标准源评测、系统自检、系统参数设置。\n收获:C++、MFC和QT界面开发、MySQL数据库、TCP/IP通信协议、WinPcap网络抓包、多线程编程"
#             },
#             {
#                 "start_date": "2011.11",
#                 "end_date": "2012.06",
#                 "proj_name": "多媒体处理实验系统",
#                 "proj_position": "软件开发负责人",
#                 "proj_content": "编写音频处理算法,包括音频文件的读写、音频文件录制与播放、频谱分析、特征参数提取、编解码、变调处理、谱减法去噪等;\n· 音频处理实验系统软件整体设计与实现。\n收获:C++、MFC界面开发、多线程编程"
#             },
#             {
#                 "start_date": "2009.09",
#                 "end_date": "2010.07",
#                 "proj_name": "智能家居系统的嵌入式解决方案",
#                 "proj_content": "项目整体规划、进度安排和成员任务分配;\n· 完成单片机对nRF24L01无线收发控制和各模块间交互的协议设计,使用IAR实现开发调试;\n· 完成温度传感器DS18B20硬件电路设计和驱动程序编写,使用Protel实现图形绘制;\n· 参与系统联调,编写各类文档,如开题和结项报告。\n收获:硬件C编程、IAR调试、Protel电路设计"
#             }
#         ],
#         "social_exp_objs": [],
#         "training_objs": [],
#         "lang_objs": [
#             {
#                 "language_name": "英语",
#                 "language_read_write": "熟练",
#                 "language_listen_speak": "良好"
#             }
#         ],
#         "cert_objs": [
#             {
#                 "langcert_lang": "英语",
#                 "langcert_name": "大学英语6级"
#             }
#         ],
#         "all_cert_objs": [
#             {
#                 "cert_name": "全国计算机等级考试二级",
#                 "cert_type": "certificate"
#             },
#             {
#                 "cert_name": "一等奖学金",
#                 "cert_type": "award"
#             },
#             {
#                 "cert_name": "校优秀毕业生",
#                 "cert_type": "award"
#             },
#             {
#                 "cert_name": "全国大学生数学建模",
#                 "cert_type": "certificate"
#             },
#             {
#                 "cert_name": "数学建模竞赛二等奖",
#                 "cert_type": "award"
#             },
#             {
#                 "cert_name": "大学英语6级",
#                 "cert_type": "certificate"
#             }
#         ],
#         "skills_objs": [
#             {
#                 "skills_name": "C++"
#             },
#             {
#                 "skills_name": "QT"
#             },
#             {
#                 "skills_name": "C/C++"
#             },
#             {
#                 "skills_name": "MFC"
#             },
#             {
#                 "skills_name": "嵌入式"
#             },
#             {
#                 "skills_name": "QT界面开发"
#             },
#             {
#                 "skills_name": "算法"
#             },
#             {
#                 "skills_name": "编解码"
#             },
#             {
#                 "skills_name": "C编程"
#             },
#             {
#                 "skills_name": "驱动程序"
#             },
#             {
#                 "skills_name": "界面开发"
#             },
#             {
#                 "skills_name": "GUI"
#             },
#             {
#                 "skills_name": "Linux环境"
#             },
#             {
#                 "skills_name": "音频处理"
#             },
#             {
#                 "skills_name": "开发调试"
#             },
#             {
#                 "skills_name": "多线程编程"
#             },
#             {
#                 "skills_name": "网络编程"
#             },
#             {
#                 "skills_name": "TCP/IP协议"
#             },
#             {
#                 "skills_name": "算法研究"
#             },
#             {
#                 "skills_name": "软件开发"
#             },
#             {
#                 "skills_name": "TCP/IP通信"
#             },
#             {
#                 "skills_name": "Win32"
#             },
#             {
#                 "skills_name": "Matlab"
#             },
#             {
#                 "skills_name": "图形绘制"
#             },
#             {
#                 "skills_name": "Shell编程"
#             },
#             {
#                 "skills_name": "IAR"
#             },
#             {
#                 "skills_name": "硬件"
#             },
#             {
#                 "skills_name": "硬件电路设计"
#             },
#             {
#                 "skills_name": "电路设计"
#             },
#             {
#                 "skills_name": "滤波"
#             },
#             {
#                 "skills_name": "LTE"
#             },
#             {
#                 "skills_name": "模块设计"
#             },
#             {
#                 "skills_name": "MySQL"
#             },
#             {
#                 "skills_name": "系统联调"
#             },
#             {
#                 "skills_name": "Hadoop"
#             },
#             {
#                 "skills_name": "hdfs"
#             },
#             {
#                 "skills_name": "智能家居系统"
#             },
#             {
#                 "skills_name": "MapReduce"
#             },
#             {
#                 "skills_name": "阅读英文文献"
#             },
#             {
#                 "skills_name": "二级C"
#             },
#             {
#                 "skills_name": "Protel"
#             },
#             {
#                 "skills_name": "抓包"
#             },
#             {
#                 "skills_name": "多媒体"
#             },
#             {
#                 "skills_name": "可视化"
#             },
#             {
#                 "skills_name": "数学建模"
#             },
#             {
#                 "skills_name": "实验指导"
#             },
#             {
#                 "skills_name": "标准测试"
#             },
#             {
#                 "skills_name": "录制"
#             }
#         ],
#         "cont_basic_info": "王     欣\n个人信息\n性    别:  女  出生年月:  1989年3月\n民    族:  汉族  籍    贯:  天津市河北区\n政治面貌:  中共党员  学    历:  硕士\n手    机:  (+86)188-0102-5570  邮    箱:  wxin_bupt@163.com\n联系地址:  北京市海淀区西土城路10号北京邮电大学29舍1103室,100876",
#         "cont_education": "2011.09-2014.03  北京邮电大学                    信息与通信工程学院        信号与信息处理专业  硕士\n· 荣获一等奖学金累计3次(10%)\n2007.09-2011.07  大连理工大学(985院校)         创新实验学院              电子信息工程专业  本科\n· 成绩排名1/57,获大连理工大学研究生保送资格\n· 荣获校学习一等奖学金累计3次(5%)、校优秀毕业生、校军训优秀个人称号、高教社杯全国大学生数学建模竞赛辽宁省一等奖、大连理工大学第十七届数学建模竞赛二等奖",
#         "cont_language": "CET-6 熟练阅读英文文献,良好的听说能力",
#         "cont_job_skill": "通过全国计算机等级考试二级C\n专业技能\n· 熟练掌握C/C++、GUI编程,具备良好的QT、MFC界面开发能力;\n· 熟悉Linux环境Shell编程、TCP/IP协议及网络编程技术和MySQL数据库;\n· 了解Hadoop分布式系统架构;\n· 具备扎实的通信专业的基础理论知识,熟悉LTE核心网相关知识;\n· 熟悉多媒体信息处理技术,了解图像和音频基本处理算法,熟练使用Matlab辅助算法研究。",
#         "cont_proj_exp": "2012.6-2013.12  话音质量客观评价系统研制  软件开发负责人  航天集团测通所\n· 研究一种考虑网络损伤的话音质量客观评价算法;\n· 设计并实现失真话音源发生器,使用MFC完成电路噪声、削波、滤波和单频噪音的模拟显示;\n· 使用MySQL构建原始与失真话音数据库;\n· 开发基于Win32平台的客观评价系统,使用QT完成五大模块设计,即标准测试源、任意源评测、标准源评测、系统自检、系统参数设置。\n收获:C++、MFC和QT界面开发、MySQL数据库、TCP/IP通信协议、WinPcap网络抓包、多线程编程\n2011.11-2012.6  多媒体处理实验系统  软件开发负责人  校级科研项目\n· 编写音频处理算法,包括音频文件的读写、音频文件录制与播放、频谱分析、特征参数提取、编解码、变调处理、谱减法去噪等;\n· 音频处理实验系统软件整体设计与实现。\n收获:C++、MFC界面开发、多线程编程\n2009.9-2010.7  智能家居系统的嵌入式解决方案  组长  校级创新性实验计划\n· 项目整体规划、进度安排和成员任务分配;\n· 完成单片机对nRF24L01无线收发控制和各模块间交互的协议设计,使用IAR实现开发调试;\n· 完成温度传感器DS18B20硬件电路设计和驱动程序编写,使用Protel实现图形绘制;\n· 参与系统联调,编写各类文档,如开题和结项报告。\n收获:硬件C编程、IAR调试、Protel电路设计",
#         "cont_internship": "2013.7-2013.10  中国科学院软件研究所总体部先导组  软件开发实习生\n· 在Hadoop集群上运行Purdue MapReduce Benchmarks上13个实例程序,并分析其相应功能;\n· 可视化软件开发,包括设置输入、输入与应用绑定、上传输入至hdfs、修改运行设置、多应用同步运行、应用运行进度显示、输出预览、添加删除应用等功能。\n收获:Hadoop、C++、QT、Linux Shell",
#         "cont_social_exp": "2011.9-2012.9  北京邮电大学  多媒体实验室  科研秘书\n· 经费申报、资料整理、通知下达等工作\n· 组织实验室内部活动,主持实验室年会活动\n2012.3-2012.7  北京邮电大学  多媒体实验课  助教\n· 设计音频相关的八个实验、完成撰写报告及实验指导任务(专题课程形式)\n2008.9-2009.7  大连理工大学  创新实验学院学生会  生活部部长\n· 负责院内卫生检查和公告栏的设计与管理\n· 组织及主持学院3.15知识竞赛活动",
#         "cont_hobby": "本人兴趣爱好广泛,在文艺和体育活动方面均有所涉猎。爱好唱歌,获得身边老师和同学们的一致好评。大二时辅修钢琴课,有几首拿手曲目。与此同时,我还对主持有着浓厚的兴趣,曾主持我院3.15知识问答比赛和实验室年会,积累了很多临场经验。在体育活动方面,热爱羽毛球、乒乓球、网球等运动,并在长跑项目上有特长。",
#         "cont_my_desc": "我乐观开朗,有进取心渴望接受新事物,善于与人沟通,曾担任院系生活部部长和实验室科研秘书职务,具备一定的组织管理经验。在学习专业课程的同时,积极参加科技创新实践活动:参加学校机电实践班,三年中完成多项实践任务;参加大学生创新性实验计划,并在项目中担任组长职位;多次参加数学建模比赛并取得了优异的成绩。最终以专业第一的成绩保送北京邮电大学攻读硕士研究生。研究生阶段的项目训练培养了我认真严谨的态度和分析问题解决问题的能力,能够更加自信的面对未来的挑战。",
#         "raw_text": "王     欣\n个人信息\n性    别:  女  出生年月:  1989年3月\n民    族:  汉族  籍    贯:  天津市河北区\n政治面貌:  中共党员  学    历:  硕士\n手    机:  (+86)188-0102-5570  邮    箱:  wxin_bupt@163.com\n联系地址:  北京市海淀区西土城路10号北京邮电大学29舍1103室,100876\n教育背景\n2011.09-2014.03  北京邮电大学                    信息与通信工程学院        信号与信息处理专业  硕士\n· 荣获一等奖学金累计3次(10%)\n2007.09-2011.07  大连理工大学(985院校)         创新实验学院              电子信息工程专业  本科\n· 成绩排名1/57,获大连理工大学研究生保送资格\n· 荣获校学习一等奖学金累计3次(5%)、校优秀毕业生、校军训优秀个人称号、高教社杯全国大学生数学建模竞赛辽宁省一等奖、大连理工大学第十七届数学建模竞赛二等奖\n个人技能\n英语技能:\nCET-6 熟练阅读英文文献,良好的听说能力\n计算机技能:\n通过全国计算机等级考试二级C\n专业技能\n· 熟练掌握C/C++、GUI编程,具备良好的QT、MFC界面开发能力;\n· 熟悉Linux环境Shell编程、TCP/IP协议及网络编程技术和MySQL数据库;\n· 了解Hadoop分布式系统架构;\n· 具备扎实的通信专业的基础理论知识,熟悉LTE核心网相关知识;\n· 熟悉多媒体信息处理技术,了解图像和音频基本处理算法,熟练使用Matlab辅助算法研究。\n项目经历\n2012.6-2013.12  话音质量客观评价系统研制  软件开发负责人  航天集团测通所\n· 研究一种考虑网络损伤的话音质量客观评价算法;\n· 设计并实现失真话音源发生器,使用MFC完成电路噪声、削波、滤波和单频噪音的模拟显示;\n· 使用MySQL构建原始与失真话音数据库;\n· 开发基于Win32平台的客观评价系统,使用QT完成五大模块设计,即标准测试源、任意源评测、标准源评测、系统自检、系统参数设置。\n收获:C++、MFC和QT界面开发、MySQL数据库、TCP/IP通信协议、WinPcap网络抓包、多线程编程\n2011.11-2012.6  多媒体处理实验系统  软件开发负责人  校级科研项目\n· 编写音频处理算法,包括音频文件的读写、音频文件录制与播放、频谱分析、特征参数提取、编解码、变调处理、谱减法去噪等;\n· 音频处理实验系统软件整体设计与实现。\n收获:C++、MFC界面开发、多线程编程\n2009.9-2010.7  智能家居系统的嵌入式解决方案  组长  校级创新性实验计划\n· 项目整体规划、进度安排和成员任务分配;\n· 完成单片机对nRF24L01无线收发控制和各模块间交互的协议设计,使用IAR实现开发调试;\n· 完成温度传感器DS18B20硬件电路设计和驱动程序编写,使用Protel实现图形绘制;\n· 参与系统联调,编写各类文档,如开题和结项报告。\n收获:硬件C编程、IAR调试、Protel电路设计\n实习经历\n2013.7-2013.10  中国科学院软件研究所总体部先导组  软件开发实习生\n· 在Hadoop集群上运行Purdue MapReduce Benchmarks上13个实例程序,并分析其相应功能;\n· 可视化软件开发,包括设置输入、输入与应用绑定、上传输入至hdfs、修改运行设置、多应用同步运行、应用运行进度显示、输出预览、添加删除应用等功能。\n收获:Hadoop、C++、QT、Linux Shell\n社会活动\n2011.9-2012.9  北京邮电大学  多媒体实验室  科研秘书\n· 经费申报、资料整理、通知下达等工作\n· 组织实验室内部活动,主持实验室年会活动\n2012.3-2012.7  北京邮电大学  多媒体实验课  助教\n· 设计音频相关的八个实验、完成撰写报告及实验指导任务(专题课程形式)\n2008.9-2009.7  大连理工大学  创新实验学院学生会  生活部部长\n· 负责院内卫生检查和公告栏的设计与管理\n· 组织及主持学院3.15知识竞赛活动\n爱好特长\n本人兴趣爱好广泛,在文艺和体育活动方面均有所涉猎。爱好唱歌,获得身边老师和同学们的一致好评。大二时辅修钢琴课,有几首拿手曲目。与此同时,我还对主持有着浓厚的兴趣,曾主持我院3.15知识问答比赛和实验室年会,积累了很多临场经验。在体育活动方面,热爱羽毛球、乒乓球、网球等运动,并在长跑项目上有特长。\n自我评价\n我乐观开朗,有进取心渴望接受新事物,善于与人沟通,曾担任院系生活部部长和实验室科研秘书职务,具备一定的组织管理经验。在学习专业课程的同时,积极参加科技创新实践活动:参加学校机电实践班,三年中完成多项实践任务;参加大学生创新性实验计划,并在项目中担任组长职位;多次参加数学建模比赛并取得了优异的成绩。最终以专业第一的成绩保送北京邮电大学攻读硕士研究生。研究生阶段的项目训练培养了我认真严谨的态度和分析问题解决问题的能力,能够更加自信的面对未来的挑战。"
#     },
#     "tags": {
#         "industries": [
#             {
#                 "tag_name": "学术/科研",
#                 "tag_weight": 1.0
#             },
#             {
#                 "tag_name": "计算机软件",
#                 "tag_weight": 0.8
#             }
#         ],
#         "pos_types": [
#             {
#                 "tag_name": "软件工程师",
#                 "tag_weight": 1.2967405915285506
#             },
#             {
#                 "tag_name": "高级软件工程师",
#                 "tag_weight": 0.42464111867529797
#             },
#             {
#                 "tag_name": "互联网软件开发工程师",
#                 "tag_weight": 0.20640756956696146
#             },
#             {
#                 "tag_name": "培训讲师",
#                 "tag_weight": 0.07455529485430036
#             },
#             {
#                 "tag_name": "软件ui设计师/工程师",
#                 "tag_weight": 0.0693440878450721
#             }
#         ],
#         "pos_tags": [
#             {
#                 "tag_name": "软件开发工程师",
#                 "tag_weight": 1.0
#             },
#             {
#                 "tag_name": "软件开发负责人",
#                 "tag_weight": 0.6
#             },
#             {
#                 "tag_name": "程序开发工程师",
#                 "tag_weight": 0.2208421289920807
#             },
#             {
#                 "tag_name": "vc++开发工程师",
#                 "tag_weight": 0.2162950336933136
#             },
#             {
#                 "tag_name": "中级软件开发工程师",
#                 "tag_weight": 0.21530293822288513
#             },
#             {
#                 "tag_name": "java培训讲师",
#                 "tag_weight": 0.208754825592041
#             },
#             {
#                 "tag_name": "网站开发工程师",
#                 "tag_weight": 0.20775904655456542
#             },
#             {
#                 "tag_name": "对日java工程师",
#                 "tag_weight": 0.20143829584121703
#             },
#             {
#                 "tag_name": "界面工程师",
#                 "tag_weight": 0.2013889968395233
#             },
#             {
#                 "tag_name": "app开发",
#                 "tag_weight": 0.20111047625541686
#             }
#         ],
#         "skills_tags": [
#             {
#                 "tag_name": "算法",
#                 "tag_weight": 1.1358849024772644
#             },
#             {
#                 "tag_name": "mfc",
#                 "tag_weight": 1.0459537124633789
#             },
#             {
#                 "tag_name": "c++",
#                 "tag_weight": 0.9527286386489868
#             },
#             {
#                 "tag_name": "qt",
#                 "tag_weight": 0.8448570871353149
#             },
#             {
#                 "tag_name": "mysql",
#                 "tag_weight": 0.8023092412948609
#             },
#             {
#                 "tag_name": "网络编程",
#                 "tag_weight": 0.5773618221282959
#             },
#             {
#                 "tag_name": "gui",
#                 "tag_weight": 0.5355766296386719
#             },
#             {
#                 "tag_name": "matlab",
#                 "tag_weight": 0.5020841598510742
#             },
#             {
#                 "tag_name": "多线程编程",
#                 "tag_weight": 0.4880584812164307
#             },
#             {
#                 "tag_name": "软件开发",
#                 "tag_weight": 0.48020486831665044
#             },
#             {
#                 "tag_name": "lte",
#                 "tag_weight": 0.4452168941497803
#             },
#             {
#                 "tag_name": "音频",
#                 "tag_weight": 0.4210971355438233
#             },
#             {
#                 "tag_name": "多媒体",
#                 "tag_weight": 0.3804926156997681
#             },
#             {
#                 "tag_name": "hadoop",
#                 "tag_weight": 0.37064964771270753
#             },
#             {
#                 "tag_name": "shell编程",
#                 "tag_weight": 0.36725172996521
#             },
#             {
#                 "tag_name": "mapreduce",
#                 "tag_weight": 0.33531415462493896
#             },
#             {
#                 "tag_name": "mysql数据库",
#                 "tag_weight": 0.3129161500930786
#             },
#             {
#                 "tag_name": "hdfs",
#                 "tag_weight": 0.3002578496932984
#             },
#             {
#                 "tag_name": "win32",
#                 "tag_weight": 0.28942283630371096
#             },
#             {
#                 "tag_name": "测试",
#                 "tag_weight": 0.27169481754302977
#             },
#             {
#                 "tag_name": "编解码",
#                 "tag_weight": 0.16785982370376587
#             },
#             {
#                 "tag_name": "界面开发",
#                 "tag_weight": 0.16318333864212037
#             },
#             {
#                 "tag_name": "信息处理",
#                 "tag_weight": 0.1305562734603882
#             },
#             {
#                 "tag_name": "硬件电路设计",
#                 "tag_weight": 0.08705153822898865
#             },
#             {
#                 "tag_name": "电路设计",
#                 "tag_weight": 0.08593865394592286
#             },
#             {
#                 "tag_name": "单片机",
#                 "tag_weight": 0.08391639351844787
#             },
#             {
#                 "tag_name": "二级c",
#                 "tag_weight": 0.08000000000000002
#             },
#             {
#                 "tag_name": "c/c++",
#                 "tag_weight": 0.08000000000000002
#             },
#             {
#                 "tag_name": "linux环境",
#                 "tag_weight": 0.08000000000000002
#             },
#             {
#                 "tag_name": "tcp/ip协议",
#                 "tag_weight": 0.08000000000000002
#             },
#             {
#                 "tag_name": "hadoop分布式系统",
#                 "tag_weight": 0.08000000000000002
#             },
#             {
#                 "tag_name": "protel",
#                 "tag_weight": 0.07865313053131104
#             },
#             {
#                 "tag_name": "驱动程序",
#                 "tag_weight": 0.07778194904327393
#             },
#             {
#                 "tag_name": "c编程",
#                 "tag_weight": 0.07555232405662538
#             },
#             {
#                 "tag_name": "传感器",
#                 "tag_weight": 0.07396164894104004
#             },
#             {
#                 "tag_name": "iar",
#                 "tag_weight": 0.07024253368377685
#             },
#             {
#                 "tag_name": "硬件",
#                 "tag_weight": 0.06975195169448853
#             }
#         ]
#     },
#     "eval": {
#         "salary": 19200
#     }
# }

# %%
# # 技能等级关键词和学历转换
# level_keywords = {
#     "精通": 4,
#     "掌握": 3,
#     "熟悉": 2,
#     "了解": 1,
# }
# education_keywords = {
#     "博士": 4,
#     "硕士": 3,
#     "本科": 2,
#     "大专": 1, 
# }

# def process_resume_data(resume_data):
#     # 提取基本信息
#     basic_info = {
#         'name': resume_data['result']['name'],
#         'email': resume_data['result']['email'],
#         'phone': resume_data['result']['phone'],
#         'major': resume_data['result']['major'],
#         'degree': education_keywords.get(resume_data['result']['degree'], 0),  # 使用转换后的学历等级
#         'skills': resume_data['result']['skills_objs']
#     }
    
#     # 简化技能列表：提取技能名和转换等级
#     skills = {}
#     for skill in basic_info['skills']:
#         skill_name = skill['skills_name']
#         skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
#         skills[skill_name] = level_keywords.get(skill_level, 1)  # 使用转换后的技能等级

#     # 评价和推荐逻辑
#     evaluation = "未评价"
#     recommended_positions = []

#     # 示例评价逻辑：基于学位和技能等级
#     if basic_info['degree'] >= 3:  # 硕士及以上
#         evaluation = "适合高级研发岗位"
#         recommended_positions.append('高级软件开发工程师')
    
#     if 'C++' in skills and skills['C++'] >= 3:
#         recommended_positions.append('C++开发工程师')

#     if 'Python' in skills and skills['Python'] >= 3:
#         recommended_positions.append('Python开发工程师')

#     # 返回处理结果
#     return {
#         'basic_info': basic_info,
#         'evaluation': evaluation,
#         'recommended_positions': recommended_positions
#     }

# processed_data = process_resume_data(resume_data)
# print(json.dumps(processed_data, indent=4, ensure_ascii=False))

# %%
import difflib

def find_closest_skill(skill_name, skills_list):
    matches = difflib.get_close_matches(skill_name, skills_list, n=1, cutoff=0.5)
    return matches[0] if matches else None

# %%
# 更新技能等级关键词
level_keywords = {
    "精通": 4,
    "熟练": 3,
    "熟悉": 2,
    "了解": 1,
}
education_keywords = {
    "博士": 4,
    "硕士": 3,
    "本科": 2,
    "大专": 1, 
}
# 定义技能和个人素质列表
skills_list = [
    "HTML5", "JavaScript", "CSS3", "Vue", "Python", "JAVA", "React", "PHP", "C++", "C语言",
    "uni-app", "jQuery", "Angular", "Bootstrap", "Node.js", "Express", "Vue.js",
    "Git", "Webpack", "MySQL", "Oracle", "SQL Server", "Linux", "Windows", "Android",
     "CAD绘图", "系统集成", "电路设计", "BIM技术", "ERP系统","控制系统", "电子信息", "通信协议", "智能化", "机器人技术", "控制算法",
    "网络设备", "网络安全", "防火墙", "TCP/IP", "OSPF", "BGP", "VPN", "交换机", "路由器", "网络系统", "网络通信",
    "软件测试", "测试计划", "测试报告", "单元测试", "功能测试", "测试用例", "软件工程", "设计模式", "架构设计", "面向对象设计", "软件开发", "系统维护", "项目管理", "API开发",
    "数据分析", "数据结构", "数据库管理", "信息化", "信息安全", "信息系统", "数据中心", "图像处理", "音视频处理"
]

qualities_list = [
    "表达能力", "PPT制作", "售后服务", "技术支持", "方案设计", 
    "责任心", "上进心", "逻辑思维", "实践经验", "团队精神", "吃苦耐劳", "认真负责", "解决问题", "主动性","积极性", "沟通","语言表达"
]
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# def semantic_similarity(text1, text2):
#     if not text1.strip() or not text2.strip() or (set(text1.split()).issubset(ENGLISH_STOP_WORDS) and set(text2.split()).issubset(ENGLISH_STOP_WORDS)):
#         return 0
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity(vectors)[0][1]

def process_resume_data(resume_data):
    # 提取基本信息
    basic_info = {
        'name': resume_data['result']['name'],
        'email': resume_data['result']['email'],
        'phone': resume_data['result']['phone'],
        'major': resume_data['result']['major'],
        'degree': education_keywords.get(resume_data['result']['degree'], 0),  # 使用转换后的学历等级
        'skills': resume_data['result']['skills_objs'],
        'quality': resume_data['result']['cont_my_desc']
    }
    # 过滤技能
    
    basic_info['quality'] = sum(basic_info['quality'].count(quality) for quality in qualities_list)

    # 简化技能列表：提取技能名和转换等级
    skills = {}
#     for skill in basic_info['skills']:
#         closest_skill = find_closest_skill(skill['skills_name'], skills_list)
#         if closest_skill:
#             skill['skills_name'] = closest_skill
#             skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
#             skill['skills_level'] = level_keywords.get(skill_level, 1)
#     for skill in basic_info['skills']:
#         closest_skill = find_closest_skill(skill['skills_name'], skills_list)
#         if closest_skill:
#             skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
#             skill_level_value = level_keywords.get(skill_level, 1)
#             if closest_skill not in skills or skill_level_value > skills[closest_skill]:
#                 skills[closest_skill] = skill_level
    for skill in basic_info['skills']:
        closest_skill = find_closest_skill(skill['skills_name'], skills_list)
        if closest_skill:
            skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
            skill_level_value = level_keywords.get(skill_level, 1)
            if closest_skill not in skills or skill_level_value > skills[closest_skill]:
                skills[closest_skill] = skill_level_value  # 使用技能等级的数值，而不是等级关键词
                
    basic_info['skills'] = skills  # 更新技能列表为简化后的字典

    # 评价和推荐逻辑
    evaluation = "未评价"
    recommended_positions = []

    # 示例评价逻辑：基于学位和技能等级
    if basic_info['degree'] >= 3:  # 硕士及以上
        evaluation = "适合高级研发岗位"
        recommended_positions.append('高级软件开发工程师')
    


    # 返回处理结果
    return {
        'basic_info': basic_info,
        'evaluation': evaluation,
        'recommended_positions': recommended_positions
    }

processed_data = process_resume_data(resume_data)
print(json.dumps(processed_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "basic_info": {
#         "name": "王欣",
#         "email": "wxin_bupt@163.com",
#         "phone": "18801025570",
#         "major": "信号与信息处理",
#         "degree": 3,
#         "skills": {
#             "C++": 1,
#             "控制算法": 1,
#             "软件开发": 1,
#             "Linux": 1,
#             "音视频处理": 1,
#             "网络通信": 1,
#             "TCP/IP": 1,
#             "Windows": 1,
#             "电路设计": 1,
#             "设计模式": 1,
#             "MySQL": 1,
#             "网络系统": 1,
#             "软件测试": 1
#         },
#         "quality": 2
#     },
#     "evaluation": "适合高级研发岗位",
#     "recommended_positions": [
#         "高级软件开发工程师"
#     ]
# }

# %%
from py2neo import Graph

# Neo4j 连接配置
uri = "bolt://localhost:7687"  # 修改为您的 Neo4j 实例地址
username = "neo4j"              # 修改为您的用户名
password = "Lmq141592"          # 修改为您的密码

# 初始化 Neo4j 连接
graph = Graph(uri, auth=(username, password))

# %%
# def build_query(ename, limit):
#     query = f"""
#     MATCH (p:Position)-[:EDUCATION]->(e:Education)
#     WHERE e.name >= {ename}
#     MATCH (p)-[:SALARY]->(s:Salary)
#     OPTIONAL MATCH (p)-[r:REQUIRES_SKILL]->(sk:Skill)
#     OPTIONAL MATCH (p)-[:QUALITY]->(q:Quality)
#     RETURN p.name AS Position, s.name AS Salary, collect({{skill: sk.name, level: r.level}}) AS Skills, e.name AS Education, q.name AS Quality
#     ORDER BY s.name DESC
#     LIMIT {limit}
#     """
#     results = graph.run(query)

#     # 将结果转换为字典列表
#     results_list = []
#     for result in results:
#         # 将每个结果项转换为字典
#         result_dict = {
#             "Position": result["Position"],
#             "Salary": result["Salary"],
#             "Skills": result["Skills"],
#             "Education": result["Education"],
#             "Quality": result["Quality"]
#         }
#         results_list.append(result_dict)

#     return results_list
def build_query(education_levels, limit):
    query = """
    MATCH (p:Position)-[:EDUCATION]->(e:Education),
          (p)-[:SALARY]->(s:Salary),
          (p)-[r:REQUIRES_SKILL]->(sk:Skill),
          (p)-[:QUALITY]->(q:Quality)
    WHERE e.name IN $education_levels
    RETURN p.name AS Position, s.name AS Salary, collect({skill: sk.name, level: r.level}) AS Skills, e.name AS Education, q.name AS Quality
    ORDER BY s.name DESC
    LIMIT $limit
    """
    # 注意：这里使用参数化查询以提高安全性和性能
    results = graph.run(query, education_levels=education_levels, limit=limit)

    # 将结果转换为字典列表
    results_list = []
    for result in results:
        # 将每个结果项转换为字典
        result_dict = {
            "Position": result["Position"],
            "Salary": result["Salary"],
            "Skills": result["Skills"],
            "Education": result["Education"],
            "Quality": result["Quality"]
        }
        results_list.append(result_dict)

    return results_list


# 使用示例
ename_min = [3,4]
results_limit = 1
query = build_query(ename_min, results_limit)
print(query)
# Out:
# [{'Position': 'AI/人工智能负责人/Leader', 'Salary': '90-120K·14薪', 'Skills': [{'level': 4, 'skill': 'C++'}, {'level': 4, 'skill': 'JAVA'}, {'level': 4, 'skill': 'Python'}], 'Education': 4, 'Quality': 2}]

# %%
# 假设以下权重基于对于岗位的重要性
WEIGHTS = {
    'skill_match': 0.4,
    'skill_level_match': 0.3,
    'education_match': 0.1,
    'quality_match': 0.1,
    'skill_coverage': 0.1  # 新增的技能覆盖率权重
}

def calculate_match_score(resume, position_requirements):
    skill_match_score = 0
    skill_level_match_score = 0
    education_match_score = 1 if resume['basic_info']['degree'] >= position_requirements['Education'] else 0
    quality_match_score = 1 if resume['basic_info']['quality'] >= position_requirements['Quality'] else 0
    total_skills = len(position_requirements['Skills'])
    total_resume_skills = len(resume['basic_info']['skills'])
    matched_skills = 0  # 匹配到的技能数量

    for skill_requirement in position_requirements['Skills']:
        skill_name = skill_requirement['skill']
        required_level = skill_requirement.get('level') 
        if skill_name in resume['basic_info']['skills'] and required_level is not None:
            level_achieved = resume['basic_info']['skills'][skill_name]
            # 确保required_level不为None且不为0来避免除以0的情况
            if required_level > 0:
                skill_match_score += 1 * min(1, level_achieved / required_level) 
                matched_skills += 1
            else:
                # 处理required_level为0或其他非预期值的情况
                print(f"Unexpected skill level for {skill_name}: {required_level}")

    if total_skills > 0:
        skill_match_score /= total_skills
        skill_coverage = matched_skills / total_resume_skills  # 计算技能覆盖率
    else:
        skill_match_score = 0
        skill_coverage = matched_skills / total_resume_skills
        
    if skill_coverage < 0.5:
        skill_coverage = 0
    
    # Calculate the weighted average match score
    match_score = (
        WEIGHTS['skill_match'] * skill_match_score +
        WEIGHTS['skill_level_match'] * skill_level_match_score +
        WEIGHTS['education_match'] * education_match_score +
        WEIGHTS['quality_match'] * quality_match_score +
        WEIGHTS['skill_coverage'] * skill_coverage  # 加入技能覆盖率权重
    )
    
    return match_score

# %%
print(processed_data)
print(query)
# Out:
# {'basic_info': {'name': '王欣', 'email': 'wxin_bupt@163.com', 'phone': '18801025570', 'major': '信号与信息处理', 'degree': 3, 'skills': {'C++': 1, '控制算法': 1, '软件开发': 1, 'Linux': 1, '音视频处理': 1, '网络通信': 1, 'TCP/IP': 1, 'Windows': 1, '电路设计': 1, '设计模式': 1, 'MySQL': 1, '网络系统': 1, '软件测试': 1}, 'quality': 2}, 'evaluation': '适合高级研发岗位', 'recommended_positions': ['高级软件开发工程师']}
# [{'Position': 'AI/人工智能负责人/Leader', 'Salary': '90-120K·14薪', 'Skills': [{'level': 4, 'skill': 'C++'}, {'level': 4, 'skill': 'JAVA'}, {'level': 4, 'skill': 'Python'}], 'Education': 4, 'Quality': 2}]

# %%
# 计算匹配得分
match_score = calculate_match_score(processed_data, query[0])
print(f"Match score for the position: {match_score:.2f}")
# Out:
# Match score for the position: 0.13

# %%
def recommend_positions(graph, resume, sort_by='match'):
    degree_to_education = {
        1: [2, 3],
        2: [2, 3],
        3: [3, 4],
        4: [3, 4]
    }

    education_levels = degree_to_education.get(resume['basic_info']['degree'], [])
    results_limit = 30

    # 使用修改后的查询函数获取岗位列表
    positions = build_query(education_levels, results_limit)

    # 为每个岗位计算匹配度
    for position in positions:
        position['match_score'] = calculate_match_score(resume, position)
    
    # 根据sort_by参数排序
    if sort_by == 'match':
        # 按匹配度排序
        positions.sort(key=lambda x: x['match_score'], reverse=True)
        # 返回匹配度最高的10个岗位的全部信息
        return positions[:10]
    else:
        # 按薪酬排序
        positions = [position for position in positions if position['match_score'] >= 0.2]
        positions.sort(key=lambda x: x['Salary'], reverse=True)
        # 返回匹配度大于0.5的薪酬最高的10个岗位
        return positions[:10]

# %%
# 推荐岗位，按匹配度排序
recommended_by_match = recommend_positions(graph, processed_data, sort_by='match')

# 或者按薪酬排序
recommended_by_salary = recommend_positions(graph, processed_data, sort_by='salary')

# %%
print(recommended_by_match[3])
#print(recommended_by_salary)
# Out:
# {'Position': 'C++软件工程师', 'Salary': '9-14K·13薪', 'Skills': [{'level': 2, 'skill': 'C++'}, {'level': 3, 'skill': '数据分析'}, {'level': 3, 'skill': '控制算法'}, {'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '系统集成'}, {'level': 4, 'skill': 'Git'}, {'level': 4, 'skill': 'SQL Server'}, {'level': 4, 'skill': '面向对象设计'}, {'level': 4, 'skill': '单元测试'}, {'level': 4, 'skill': '电子信息'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '控制系统'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': '软件测试'}, {'level': 4, 'skill': '设计模式'}, {'level': 4, 'skill': '数据结构'}, {'level': 4, 'skill': 'MySQL'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '架构设计'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': '图像处理'}, {'level': 4, 'skill': 'Python'}, {'level': 4, 'skill': '通信协议'}, {'level': 4, 'skill': '软件工程'}], 'Education': 3, 'Quality': 1, 'match_score': 0.32260208926875594}

# %%
cypher_query = """
MATCH (p:Position)-[:EDUCATION]->(e:Education),
        (p)-[:SALARY]->(s:Salary),
        (p)-[r:REQUIRES_SKILL]->(sk:Skill),
        (p)-[:QUALITY]->(q:Quality),
        (cn:Company)-[:OFFERS]->(p),
        (cn:Company)-[:LOCATED_IN]->(c:City)
WHERE e.name IN [2,3] AND c.name = '深圳'
RETURN DISTINCT p.name AS Position, s.name AS Salary, collect({skill: sk.name, level: r.level}) AS Skills, e.name AS Education, q.name AS Quality,cn.name AS Company,c.name AS City
ORDER BY s.name DESC
LIMIT 10
"""

# 执行查询并处理结果
result = graph.run(cypher_query)

# 输出查询结果
for record in result:
    print(record)
# Out:
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	3	1	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	3	5	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	3	4	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	3	3	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	3	2	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	2	1	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	2	5	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	2	4	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	2	3	'上海思尔芯技术股份有限公司'	'深圳'
# '软件工程师'	'9-14K·14薪'	[{'level': 4, 'skill': 'JAVA'}, {'level': 2, 'skill': '防火墙'}, {'level': 4, 'skill': '路由器'}, {'level': 4, 'skill': '交换机'}, {'level': 3, 'skill': '系统维护'}, {'level': 4, 'skill': '数据库管理'}, {'level': 4, 'skill': 'Webpack'}, {'level': 3, 'skill': '信息化'}, {'level': 4, 'skill': 'Node.js'}, {'level': 4, 'skill': 'Vue.js'}, {'level': 4, 'skill': 'uni-app'}, {'level': 4, 'skill': 'CSS3'}, {'level': 4, 'skill': '信息安全'}, {'level': 4, 'skill': 'React'}, {'level': 2, 'skill': '面向对象设计'}, {'level': 3, 'skill': '网络系统'}, {'level': 2, 'skill': '数据分析'}, {'level': 4, 'skill': '功能测试'}, {'level': 4, 'skill': 'jQuery'}, {'level': 3, 'skill': 'Android'}, {'level': 4, 'skill': 'Angular'}, {'level': 2, 'skill': 'PHP'}, {'level': 2, 'skill': '测试用例'}, {'level': 4, 'skill': 'HTML5'}, {'level': 4, 'skill': '系统集成'}, {'level': 2, 'skill': '单元测试'}, {'level': 3, 'skill': '设计模式'}, {'level': 2, 'skill': '控制算法'}, {'level': 3, 'skill': 'TCP/IP'}, {'level': 2, 'skill': '通信协议'}, {'level': 3, 'skill': 'Git'}, {'level': 3, 'skill': '架构设计'}, {'level': 4, 'skill': 'ERP系统'}, {'level': 2, 'skill': '控制系统'}, {'level': 4, 'skill': '图像处理'}, {'level': 2, 'skill': '信息系统'}, {'level': 3, 'skill': 'SQL Server'}, {'level': 2, 'skill': '网络通信'}, {'level': 4, 'skill': 'Vue'}, {'level': 4, 'skill': 'MySQL'}, {'level': 2, 'skill': 'Express'}, {'level': 3, 'skill': '电子信息'}, {'level': 4, 'skill': 'C++'}, {'level': 3, 'skill': '软件工程'}, {'level': 4, 'skill': '测试计划'}, {'level': 4, 'skill': '软件开发'}, {'level': 4, 'skill': 'Linux'}, {'level': 4, 'skill': 'JavaScript'}, {'level': 2, 'skill': 'Python'}, {'level': 4, 'skill': 'Oracle'}, {'level': 4, 'skill': '智能化'}, {'level': 4, 'skill': '项目管理'}, {'level': 4, 'skill': 'C语言'}, {'level': 3, 'skill': '数据结构'}, {'level': 4, 'skill': 'Windows'}, {'level': 4, 'skill': '软件测试'}, {'level': 3, 'skill': '测试报告'}]	2	2	'上海思尔芯技术股份有限公司'	'深圳'

# %%
import difflib

def find_closest_skill(skill_name, skills_list):
    matches = difflib.get_close_matches(skill_name, skills_list, n=1, cutoff=0.5)
    return matches[0] if matches else None

# %%
# 更新技能等级关键词
level_keywords = {
    "精通": 4,
    "熟练": 3,
    "熟悉": 2,
    "了解": 1,
}
education_keywords = {
    "博士": 4,
    "硕士": 3,
    "本科": 2,
    "大专": 1, 
}
# 定义技能和个人素质列表
skills_list = [
    "HTML5", "JavaScript", "CSS3", "Vue", "Python", "JAVA", "React", "PHP", "C++", "C语言",
    "uni-app", "jQuery", "Angular", "Bootstrap", "Node.js", "Express", "Vue.js",
    "Git", "Webpack", "MySQL", "Oracle", "SQL Server", "Linux", "Windows", "Android",
     "CAD绘图", "系统集成", "电路设计", "BIM技术", "ERP系统","控制系统", "电子信息", "通信协议", "智能化", "机器人技术", "控制算法",
    "网络设备", "网络安全", "防火墙", "TCP/IP", "OSPF", "BGP", "VPN", "交换机", "路由器", "网络系统", "网络通信",
    "软件测试", "测试计划", "测试报告", "单元测试", "功能测试", "测试用例", "软件工程", "设计模式", "架构设计", "面向对象设计", "软件开发", "系统维护", "项目管理", "API开发",
    "数据分析", "数据结构", "数据库管理", "信息化", "信息安全", "信息系统", "数据中心", "图像处理", "音视频处理"
]

qualities_list = [
    "表达能力", "PPT制作", "售后服务", "技术支持", "方案设计", 
    "责任心", "上进心", "逻辑思维", "实践经验", "团队精神", "吃苦耐劳", "认真负责", "解决问题", "主动性","积极性", "沟通","语言表达"
]
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity
# from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# def semantic_similarity(text1, text2):
#     if not text1.strip() or not text2.strip() or (set(text1.split()).issubset(ENGLISH_STOP_WORDS) and set(text2.split()).issubset(ENGLISH_STOP_WORDS)):
#         return 0
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity(vectors)[0][1]

def process_resume_data(resume_data):
    # 提取基本信息
    basic_info = {
        'name': resume_data['result']['name'],
        'email': resume_data['result']['email'],
        'phone': resume_data['result']['phone'],
        'major': resume_data['result']['major'],
        'degree': education_keywords.get(resume_data['result']['degree'], 0),  # 使用转换后的学历等级
        'skills': resume_data['result']['skills_objs'],
        'quality': resume_data['result']['cont_my_desc']
    }
    # 过滤技能
    
    basic_info['quality'] = sum(basic_info['quality'].count(quality) for quality in qualities_list)

    # 简化技能列表：提取技能名和转换等级
    skills = {}
#     for skill in basic_info['skills']:
#         closest_skill = find_closest_skill(skill['skills_name'], skills_list)
#         if closest_skill:
#             skill['skills_name'] = closest_skill
#             skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
#             skill['skills_level'] = level_keywords.get(skill_level, 1)
    for skill in basic_info['skills']:
        closest_skill = find_closest_skill(skill['skills_name'], skills_list)
        if closest_skill:
            skill_level = skill.get('skills_level', '了解')  # 默认等级为了解
            skill_level_value = level_keywords.get(skill_level, 1)
            if closest_skill not in skills or skill_level_value > skills[closest_skill]:
                skills[closest_skill] = skill_level

    basic_info['skills'] = skills  # 更新技能列表为简化后的字典

    # 评价和推荐逻辑
    evaluation = "未评价"
    recommended_positions = []

    # 示例评价逻辑：基于学位和技能等级
    if basic_info['degree'] >= 3:  # 硕士及以上
        evaluation = "适合高级研发岗位"
        recommended_positions.append('高级软件开发工程师')
    


    # 返回处理结果
    return {
        'basic_info': basic_info,
        'evaluation': evaluation,
        'recommended_positions': recommended_positions
    }

processed_data = process_resume_data(resume_data)
print(json.dumps(processed_data, indent=4, ensure_ascii=False))
# Out:
# {
#     "basic_info": {
#         "name": "王欣",
#         "email": "wxin_bupt@163.com",
#         "phone": "18801025570",
#         "major": "信号与信息处理",
#         "degree": 3,
#         "skills": {
#             "C++": 3,
#             "MySQL": 3,
#             "C语言": 3,
#             "Linux": 2,
#             "SQL Server": 2,
#             "TCP/IP": 2,
#             "网络通信": 2,
#             "Bootstrap": 1,
#             "设计模式": 1,
#             "网络系统": 1,
#             "控制算法": 2,
#             "React": 2,
#             "数据库管理": 1,
#             "软件工程": 1,
#             "交换机": 1,
#             "Python": 1
#         },
#         "quality": 2
#     },
#     "evaluation": "适合高级研发岗位",
#     "recommended_positions": [
#         "高级软件开发工程师"
#     ]
# }
